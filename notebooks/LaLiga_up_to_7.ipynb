# %%
import os
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plot
from pathlib import Path

# %%
dir = Path.cwd()
laliga_path = dir / "laliga.sqlite"

#We do this execption to check in the working driectory or the parent for the "laliga.sqlite" file.

try:
    conn = sqlite3.connect(laliga_path)
except sqlite3.OperationalError as e:
    print(f"Not found in current directory ({laliga_path}), trying for parent...")
    parent_path = dir.parent / "laliga.sqlite"
    try:
        conn = sqlite3.connect(parent_path)
        print(f"Connection succes: {parent_path}")
    except sqlite3.OperationalError:
        raise FileNotFoundError(
            f"Not found 'laliga.sqlite' neither in {laliga_path} nor in {parent_path}"
        ) from e

# %%
df = pd.read_sql("SELECT * FROM Matches;", conn)
df
# Out:
#           season  division  matchday     date  time        home_team  \
# 0      1928-1929         1         1  2/10/29  None      Arenas Club
# 1      1928-1929         1         1  2/10/29  None         Espanyol
# 2      1928-1929         1         1  2/10/29  None      Real Madrid
# 3      1928-1929         1         1  2/10/29  None         Donostia
# 4      1928-1929         1         1  2/12/29  None           Racing
# ...          ...       ...       ...      ...   ...              ...
# 48775  2021-2022         2        42  5/29/22  None      Real Oviedo
# 48776  2021-2022         2        42  5/29/22  None  Real Sociedad B
# 48777  2021-2022         2        42  5/29/22  None   Sporting Gijón
# 48778  2021-2022         2        42  5/29/22  None      CD Tenerife
# 48779  2021-2022         2        42  5/29/22  None  Real Valladolid
#
#              away_team score
# 0      Athletic Madrid   2:3
# 1           Real Unión   3:2
# 2            Catalunya   5:0
# 3             Athletic   1:1
# 4            Barcelona   0:2
# ...                ...   ...
# 48775         UD Ibiza  None
# 48776    Real Zaragoza  None
# 48777    UD Las Palmas  None
# 48778     FC Cartagena  None
# 48779        SD Huesca  None
#
# [48780 rows x 8 columns]

# %% [markdown]
# # Exercise 1

# %% [markdown]
# To be able to make a pie chart with the percentages of the home team wins, visitor team wins and ties, we need to extract the data from our df.

# %%
matches = df.copy()

# %%
valid_matches = matches[matches['score'].notna() & matches['score'].str.contains(':')].copy()

# %%
valid_matches[['home_goals', 'away_goals']] = (valid_matches['score'].str.split(':', expand=True).astype(int))
valid_matches
# Out:
#           season  division  matchday     date      time        home_team  \
# 0      1928-1929         1         1  2/10/29      None      Arenas Club
# 1      1928-1929         1         1  2/10/29      None         Espanyol
# 2      1928-1929         1         1  2/10/29      None      Real Madrid
# 3      1928-1929         1         1  2/10/29      None         Donostia
# 4      1928-1929         1         1  2/12/29      None           Racing
# ...          ...       ...       ...      ...       ...              ...
# 48345  2021-2022         2         3  8/28/21  10:00 PM     Ponferradina
# 48346  2021-2022         2         3  8/29/21   5:00 PM    SD Amorebieta
# 48347  2021-2022         2         3  8/29/21   7:30 PM          CD Lugo
# 48348  2021-2022         2         3  8/29/21   7:30 PM  Real Sociedad B
# 48349  2021-2022         2         3  8/29/21  10:00 PM        Burgos CF
#
#              away_team score  home_goals  away_goals
# 0      Athletic Madrid   2:3           2           3
# 1           Real Unión   3:2           3           2
# 2            Catalunya   5:0           5           0
# 3             Athletic   1:1           1           1
# 4            Barcelona   0:2           0           2
# ...                ...   ...         ...         ...
# 48345           Girona   2:1           2           1
# 48346       UD Almería   2:1           2           1
# 48347  Real Valladolid   0:2           0           2
# 48348   CF Fuenlabrada   0:0           0           0
# 48349         SD Eibar   0:1           0           1
#
# [48000 rows x 10 columns]

# %%
def get_result(row):
    if row['home_goals'] > row['away_goals']:
        return '1'
    elif row['home_goals'] < row['away_goals']:
        return '2'
    else:
        return 'X'

# %%
valid_matches['result'] = valid_matches.apply(get_result, axis=1)
valid_matches
# Out:
#           season  division  matchday     date      time        home_team  \
# 0      1928-1929         1         1  2/10/29      None      Arenas Club
# 1      1928-1929         1         1  2/10/29      None         Espanyol
# 2      1928-1929         1         1  2/10/29      None      Real Madrid
# 3      1928-1929         1         1  2/10/29      None         Donostia
# 4      1928-1929         1         1  2/12/29      None           Racing
# ...          ...       ...       ...      ...       ...              ...
# 48345  2021-2022         2         3  8/28/21  10:00 PM     Ponferradina
# 48346  2021-2022         2         3  8/29/21   5:00 PM    SD Amorebieta
# 48347  2021-2022         2         3  8/29/21   7:30 PM          CD Lugo
# 48348  2021-2022         2         3  8/29/21   7:30 PM  Real Sociedad B
# 48349  2021-2022         2         3  8/29/21  10:00 PM        Burgos CF
#
#              away_team score  home_goals  away_goals result
# 0      Athletic Madrid   2:3           2           3      2
# 1           Real Unión   3:2           3           2      1
# 2            Catalunya   5:0           5           0      1
# 3             Athletic   1:1           1           1      X
# 4            Barcelona   0:2           0           2      2
# ...                ...   ...         ...         ...    ...
# 48345           Girona   2:1           2           1      1
# 48346       UD Almería   2:1           2           1      1
# 48347  Real Valladolid   0:2           0           2      2
# 48348   CF Fuenlabrada   0:0           0           0      X
# 48349         SD Eibar   0:1           0           1      2
#
# [48000 rows x 11 columns]

# %%
result_counts = valid_matches['result'].value_counts()
result_counts
# Out:
# result
# 1    25321
# X    12280
# 2    10399
# Name: count, dtype: int64

# %%
result_counts.plot(kind="pie", autopct = '%1.2f%%', legend = False, ylabel='')
# Out:
# <Axes: >

# %% [markdown]
# We can see clearly that most matches are won by the local team. We could say that the local team has advantatge over the visitor.

# %% [markdown]
# # Exercise 2

# %% [markdown]
# First, we need to sort the data to get the total goals for each team.

# %%
first_division = valid_matches[valid_matches['division'] == 1].copy()

# %%
division1 = first_division.copy()

# %%
home_goals_scored = division1.groupby('home_team')['home_goals'].sum()

# %%
away_goals_scored = division1.groupby('away_team')['away_goals'].sum()

# %%
total_goals_scored = home_goals_scored.add(away_goals_scored, fill_value=0)

# %%
total_goals_scored.sort_values(ascending=False).head()
# Out:
# home_team
# Barcelona          6267
# Real Madrid        6249
# Athletic           4802
# Valencia           4615
# Atlético Madrid    4184
# dtype: int64

# %% [markdown]
# Secondly, we will compute the total goals conceded for each team.

# %%
home_goals_conceded = division1.groupby('home_team')['away_goals'].sum()

# %%
away_goals_conceded = division1.groupby('away_team')['home_goals'].sum()

# %%
total_goals_conceded = home_goals_conceded.add(away_goals_conceded, fill_value=0)

# %%
team_goals = pd.DataFrame({'Goals Scored': total_goals_scored, 'Goals Conceded': total_goals_conceded})
team_goals
# Out:
#                Goals Scored  Goals Conceded
# home_team
# AD Almería               72             116
# Alavés                  608             852
# Albacete                320             410
# Arenas Club             227             308
# Ath. Aviación           113              65
# ...                     ...             ...
# UD Salamanca            425             581
# UE Lleida                29              48
# Valencia               4615            3649
# Villarreal             1123             986
# Xerez CD                 38              66
#
# [68 rows x 2 columns]

# %%
top10_scored = team_goals.sort_values(by='Goals Scored', ascending=False).head(10)

# %%
top10_scored['Goals Scored'].plot(kind='bar')
plot.title('Top 10 teams by Goals Scored (First Division)')
plot.ylabel('Goals Scored')
plot.xlabel('Team')
plot.xticks(rotation=45, ha='right')
plot.show()

# %%
top10_conceded = team_goals.sort_values(by='Goals Conceded', ascending=False).head(10)

# %%
top10_conceded['Goals Conceded'].plot(kind='bar', color='red')
plot.title('Top 10 teams by Goals Conceded (First Division)')
plot.ylabel('Goals Conceded')
plot.xlabel('Team')
plot.xticks(rotation=45, ha='right')
plot.show()

# %% [markdown]
# Now, we will compute the matches with the biggest goal difference.

# %%
first_division['goal_difference'] = (first_division['home_goals'] - first_division['away_goals']).abs()

# %%
biggest_wins = first_division.sort_values(by='goal_difference', ascending=False).head(10)
biggest_wins
# Out:
#           season  division  matchday      date  time        home_team  \
# 225    1930-1931         1        10    2/8/31  None         Athletic
# 936    1940-1941         1         1   9/29/40  None       Sevilla FC
# 2787   1950-1951         1        11  11/19/50  None         Athletic
# 1168   1941-1942         1        15   1/11/42  None         Athletic
# 1071   1941-1942         1         1   9/28/41  None       Sevilla FC
# 3629   1953-1954         1        26   3/28/54  None        Barcelona
# 10024  1978-1979         1        16   1/14/79  None        Barcelona
# 408    1932-1933         1        10   1/29/33  None           Racing
# 5027   1959-1960         1        21    2/7/60  None      Real Madrid
# 3911   1955-1956         1         1   9/11/55  None  Atlético Madrid
#
#             away_team score  home_goals  away_goals result  goal_difference
# 225         Barcelona  12:1          12           1      1               11
# 936         Barcelona  11:1          11           1      1               10
# 2787           Lérida  10:0          10           0      1               10
# 1168    Celta de Vigo  10:0          10           0      1               10
# 1071      Real Oviedo  10:0          10           0      1               10
# 3629      Real Oviedo   9:0           9           0      1                9
# 10024  Rayo Vallecano   9:0           9           0      1                9
# 408            Alavés   9:0           9           0      1                9
# 5027         Elche CF  11:2          11           2      1                9
# 3911      Hércules CF   9:0           9           0      1                9

# %% [markdown]
# What we have seen is that the two teams with the biggest number of goals are Barcelona and Real Madrid. The two teams with the largest number of conceded goals are Espanyol and Athletic. Finally, the match with the biggest difference in goals is athelic vs Barcelona in season 1930-1931.

# %% [markdown]
# # Exercise 3

# %%
df1 = matches.copy()

# %%
df1['new_date'] = pd.to_datetime(df1['date'], format='%m/%d/%y', errors='coerce')
df1
# Out:
#           season  division  matchday     date  time        home_team  \
# 0      1928-1929         1         1  2/10/29  None      Arenas Club
# 1      1928-1929         1         1  2/10/29  None         Espanyol
# 2      1928-1929         1         1  2/10/29  None      Real Madrid
# 3      1928-1929         1         1  2/10/29  None         Donostia
# 4      1928-1929         1         1  2/12/29  None           Racing
# ...          ...       ...       ...      ...   ...              ...
# 48775  2021-2022         2        42  5/29/22  None      Real Oviedo
# 48776  2021-2022         2        42  5/29/22  None  Real Sociedad B
# 48777  2021-2022         2        42  5/29/22  None   Sporting Gijón
# 48778  2021-2022         2        42  5/29/22  None      CD Tenerife
# 48779  2021-2022         2        42  5/29/22  None  Real Valladolid
#
#              away_team score   new_date
# 0      Athletic Madrid   2:3 2029-02-10
# 1           Real Unión   3:2 2029-02-10
# 2            Catalunya   5:0 2029-02-10
# 3             Athletic   1:1 2029-02-10
# 4            Barcelona   0:2 2029-02-12
# ...                ...   ...        ...
# 48775         UD Ibiza  None 2022-05-29
# 48776    Real Zaragoza  None 2022-05-29
# 48777    UD Las Palmas  None 2022-05-29
# 48778     FC Cartagena  None 2022-05-29
# 48779        SD Huesca  None 2022-05-29
#
# [48780 rows x 9 columns]

# %%
df1['weekday'] = df1['new_date'].dt.day_name()

# %%
weekday_counts = df1['weekday'].value_counts()
weekday_counts
# Out:
# weekday
# Sunday       25195
# Saturday     20073
# Wednesday     1389
# Friday         850
# Monday         621
# Thursday       345
# Tuesday        307
# Name: count, dtype: int64

# %%
weekday_counts.plot(kind="bar")
# Out:
# <Axes: xlabel='weekday'>

# %%
df1['hour'] = pd.to_datetime(df1['time'], format='%I:%M %p', errors='coerce').dt.hour

# %%
hours = df1['hour'].dropna()

# %%
plot.hist(hours, bins=range(11,23), edgecolor='black')
plot.xlabel('Hour of the day.')
plot.ylabel('Number of matches.')
plot.show()

# %% [markdown]
# As we can see in both charts, matches mostly happen on weekends, especially on Sundays. Regarding the hours, they are more distributed during the afternoon and evening, mostly between 18 and 19.

# %%
df1_2000 = df1[df1['season'] == '2000-2001'].copy()
df1_2020 = df1[df1['season'] == '2020-2021'].copy()
df1_2000
# Out:
#           season  division  matchday     date     time       home_team  \
# 17838  2000-2001         1         1   9/9/00  8:15 PM   Real Sociedad
# 17839  2000-2001         1         1   9/9/00  9:00 PM   Real Zaragoza
# 17840  2000-2001         1         1   9/9/00  9:00 PM       Barcelona
# 17841  2000-2001         1         1   9/9/00  9:00 PM  Dep. La Coruña
# 17842  2000-2001         1         1   9/9/00  9:00 PM     Real Madrid
# ...          ...       ...       ...      ...      ...             ...
# 38693  2000-2001         2        42  6/17/01     None        Albacete
# 38694  2000-2001         2        42  6/17/01     None        Elche CF
# 38695  2000-2001         2        42  6/17/01     None  Sporting Gijón
# 38696  2000-2001         2        42  6/17/01     None    Real Jaén CF
# 38697  2000-2001         2        42  6/17/01     None          Getafe
#
#              away_team score   new_date   weekday  hour
# 17838           Racing   2:2 2000-09-09  Saturday  20.0
# 17839         Espanyol   1:2 2000-09-09  Saturday  21.0
# 17840        Málaga CF   2:1 2000-09-09  Saturday  21.0
# 17841         Athletic   2:0 2000-09-09  Saturday  21.0
# 17842         Valencia   2:1 2000-09-09  Saturday  21.0
# ...                ...   ...        ...       ...   ...
# 38693  Uni. Las Palmas   2:3 2001-06-17    Sunday   NaN
# 38694    SD Compostela   2:2 2001-06-17    Sunday   NaN
# 38695       Córdoba CF   2:2 2001-06-17    Sunday   NaN
# 38696       Real Betis   0:2 2001-06-17    Sunday   NaN
# 38697  Atlético Madrid   0:1 2001-06-17    Sunday   NaN
#
# [842 rows x 11 columns]

# %%
weekday_counts_2000 = df1_2000['weekday'].value_counts()
weekday_counts_2020 = df1_2020['weekday'].value_counts()

# %%
weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekday_counts_2000 = weekday_counts_2000.reindex(weekday_order).fillna(0)
weekday_counts_2020 = weekday_counts_2020.reindex(weekday_order).fillna(0)

# %%
fig, axes = plot.subplots(1, 2, sharey=True)

weekday_counts_2000.plot(kind='bar', ax=axes[0], color='blue')
axes[0].set_title('2000–2001')
axes[0].set_ylabel('Number of matches')
axes[0].tick_params(axis='x', rotation=45)

weekday_counts_2020.plot(kind='bar', ax=axes[1], color='red')
axes[1].set_title('2020–2021')
axes[1].tick_params(axis='x', rotation=45)

plot.show()

# %% [markdown]
# Now, we can see that the distribution of matches has changed during the week in recent years. We cannot appreciate this in the previous charts, since this difference has happened recently and most of the data is distributed as in the chart 2000-2001.

# %%
hours_2000 = df1_2000['hour'].dropna()
hours_2020 = df1_2020['hour'].dropna()

# %%
fig, axes = plot.subplots(1, 2, sharey=True)

axes[0].hist(hours_2000, bins=range(11,24), edgecolor='black', color='blue')
axes[0].set_title('2000–2001')
axes[0].set_xlabel('Hour of the day')
axes[0].set_ylabel('Number of matches')
axes[0].set_xticks(range(11,24,2))

axes[1].hist(hours_2020, bins=range(11,24), edgecolor='black', color='red')
axes[1].set_title('2020–2021')
axes[1].set_xlabel('Hour of the day')
axes[1].set_xticks(range(11,24,2))

plot.show()

# %% [markdown]
# Again, this is a clear indicator of the change of tendency of the kickoff hours of the matches, which we could not see in the first charts as we explained before.

# %% [markdown]
# # Exercise 4

# %%
df4 = first_division.copy()

# %%
df4_season = df4[(df4['season'] == '2020-2021')].copy()

# %%
teams_sorted = sorted(set(df4_season['home_team']).union(df4_season['away_team']))

# %% [markdown]
# The objective is to get a table as similar as possible to that from Wikipedia. Hence, it is not hardcoded given the aim of the exercice :)

# %%
team_abbr = {
    'Alavés': 'ALA',
    'Athletic': 'ATH',
    'Atlético Madrid': 'ATL',
    'Barcelona': 'BAR',
    'Real Betis': 'BET',
    'Cádiz CF': 'CAD',
    'Celta de Vigo': 'CEL',
    'Elche CF': 'ELC',
    'Getafe': 'GET',
    'Granada CF': 'GRA',
    'SD Huesca': 'HUE',
    'Levante': 'LEV',
    'Real Madrid': 'RMA',
    'CA Osasuna': 'OSA',
    'Real Sociedad': 'RSO',
    'Real Valladolid': 'RVA',
    'SD Eibar': 'EIB',
    'Sevilla FC': 'SEV',
    'Valencia': 'VAL',
    'Villarreal': 'VIL'
}

# %%
team_abbr_list = list(team_abbr.values())

# %%
df4_season['away_abbr'] = df4_season['away_team'].map(team_abbr)

# %%
df4_season['resultado'] = df4_season['home_goals'].astype(str) + '-' + df4_season['away_goals'].astype(str)

# %%
table4 = ( df4_season.pivot_table(index='home_team', columns='away_abbr', values='resultado',aggfunc='first', fill_value='—')
            .reindex(index=teams_sorted, columns=team_abbr_list, fill_value=0)
            .rename_axis(index=None, columns="Local \ Visitante"))

# %% [markdown]
# Coloring the table

# %%
def color_result(val):
    if isinstance(val, str):
        if val == '—':
            return 'background-color: #f6f6f6;'
        elif '-' in val:
            goles = val.split('-')
            if len(goles) == 2 and goles[0].isdigit() and goles[1].isdigit():
                g1, g2 = map(int, goles)
                if g1 > g2:
                    return 'background-color: #c7f7c4;'
                elif g1 < g2:
                    return 'background-color: #f7c4c4;'
                else:
                    return 'background-color: #f7f3c4;'
    return ''

# %%
table4_a = (table4.style
    .applymap(color_result)
    .set_table_styles([
        {'selector': 'table',
         'props': [('border-collapse', 'collapse'),
                   ('border', '2px solid #000')]},
        {'selector': 'th, td',
         'props': [('border', '1px solid #000 !important'),
                   ('padding', '6px'),
                   ('text-align', 'center')]},
        {'selector': 'th', 'props': [
            ('background-color', '#f6f6f6'),
            ('color', '#2e2a8c'),
            ('border','1px solid #000 !important'),
            ('padding','6px'),
            ('text-align','center')
        ]},
        {'selector': 'thead tr:first-child th:first-child', 'props': [
            ('background-color', '#f6f6f6'),
            ('color', 'black'),
            ('text-transform', 'none'),
            ('font-weight', 'bold')
        ]}
    ])
)

# %%
table4_a
# Out:
# <style type="text/css">
# #T_2f521 table {
#   border-collapse: collapse;
#   border: 2px solid #000;
# }
# #T_2f521 th {
#   border: 1px solid #000 !important;
#   padding: 6px;
#   text-align: center;
# }
# #T_2f521  td {
#   border: 1px solid #000 !important;
#   padding: 6px;
#   text-align: center;
# }
# #T_2f521 th {
#   background-color: #f6f6f6;
#   color: #2e2a8c;
#   border: 1px solid #000 !important;
#   padding: 6px;
#   text-align: center;
# }
# #T_2f521 thead tr:first-child th:first-child {
#   background-color: #f6f6f6;
#   color: black;
#   text-transform: none;
#   font-weight: bold;
# }
# #T_2f521_row0_col0, #T_2f521_row1_col1, #T_2f521_row2_col2, #T_2f521_row3_col3, #T_2f521_row4_col13, #T_2f521_row5_col6, #T_2f521_row6_col5, #T_2f521_row7_col7, #T_2f521_row8_col8, #T_2f521_row9_col9, #T_2f521_row10_col11, #T_2f521_row11_col4, #T_2f521_row12_col12, #T_2f521_row13_col14, #T_2f521_row14_col15, #T_2f521_row15_col16, #T_2f521_row16_col10, #T_2f521_row17_col17, #T_2f521_row18_col18, #T_2f521_row19_col19 {
#   background-color: #f6f6f6;
# }
# #T_2f521_row0_col1, #T_2f521_row0_col9, #T_2f521_row0_col10, #T_2f521_row0_col15, #T_2f521_row0_col16, #T_2f521_row0_col19, #T_2f521_row1_col2, #T_2f521_row1_col4, #T_2f521_row1_col7, #T_2f521_row1_col8, #T_2f521_row1_col9, #T_2f521_row1_col10, #T_2f521_row1_col11, #T_2f521_row1_col17, #T_2f521_row2_col0, #T_2f521_row2_col1, #T_2f521_row2_col3, #T_2f521_row2_col4, #T_2f521_row2_col5, #T_2f521_row2_col7, #T_2f521_row2_col8, #T_2f521_row2_col9, #T_2f521_row2_col10, #T_2f521_row2_col13, #T_2f521_row2_col14, #T_2f521_row2_col15, #T_2f521_row2_col16, #T_2f521_row2_col17, #T_2f521_row2_col18, #T_2f521_row3_col0, #T_2f521_row3_col1, #T_2f521_row3_col4, #T_2f521_row3_col7, #T_2f521_row3_col8, #T_2f521_row3_col10, #T_2f521_row3_col11, #T_2f521_row3_col13, #T_2f521_row3_col14, #T_2f521_row3_col15, #T_2f521_row3_col19, #T_2f521_row4_col1, #T_2f521_row4_col
# #T_2f521_row0_col3, #T_2f521_row0_col5, #T_2f521_row0_col8, #T_2f521_row0_col11, #T_2f521_row0_col14, #T_2f521_row0_col18, #T_2f521_row1_col0, #T_2f521_row1_col13, #T_2f521_row1_col15, #T_2f521_row1_col16, #T_2f521_row1_col18, #T_2f521_row1_col19, #T_2f521_row2_col6, #T_2f521_row2_col12, #T_2f521_row2_col19, #T_2f521_row3_col2, #T_2f521_row3_col5, #T_2f521_row3_col16, #T_2f521_row3_col17, #T_2f521_row3_col18, #T_2f521_row4_col0, #T_2f521_row4_col8, #T_2f521_row4_col10, #T_2f521_row4_col12, #T_2f521_row4_col15, #T_2f521_row5_col1, #T_2f521_row5_col15, #T_2f521_row5_col16, #T_2f521_row6_col6, #T_2f521_row6_col9, #T_2f521_row6_col11, #T_2f521_row6_col15, #T_2f521_row6_col19, #T_2f521_row7_col4, #T_2f521_row7_col5, #T_2f521_row7_col6, #T_2f521_row7_col10, #T_2f521_row7_col12, #T_2f521_row7_col13, #T_2f521_row7_col15, #T_2f521_row7_col19, #T_2f521_row8_col0, #T_2f521_row8_col1, #T_2f521_row8_col2, #T_2f521_row8_col6, #T_2f521_row8_col7, #T_2f521_row8_col12, #T_2f521_row9_col6, #T_2f521_row9_col8, #T_2f521_row9_col10, #T_2f521_row9_col11, #T_2f521_row10_col0, #T_2f521_row10_col1, #T_2f521_row10_col2, #T_2f521_row10_col3, #T_2f521_row10_col5, #T_2f521_row10_col6, #T_2f521_row10_col7, #T_2f521_row10_col9, #T_2f521_row10_col15, #T_2

# %% [markdown]
# Using a gradient of colors is the easiest option. First we extract the match difference for each cell.

# %%
def goal_diff(cell):
    if not isinstance(cell, str) or '-' not in cell:
        return np.nan
    a, b = cell.split('-')
    if a.isdigit() and b.isdigit():
        return int(a) - int(b)
    return np.nan

# %%
gdiff = table4.applymap(goal_diff)

# %%
max_abs = np.nanmax(np.abs(gdiff.values)) or 1
vmin, vmax = -max_abs, max_abs

# %%
table4_b = (
    table4.style
    .background_gradient(cmap='RdYlGn', gmap=gdiff, vmin=vmin, vmax=vmax, axis = None)
    .applymap(lambda v: 'background-color:#f6f6f6; color:#000;' if v == '—' else '')
    .set_table_styles([
        {'selector': 'table', 'props': [('border-collapse','collapse'),
                                        ('border','2px solid #000')]},
        {'selector': 'th, td','props': [('border','1px solid #000 !important'),
                                        ('padding','6px'),
                                        ('text-align','center')]},
        {'selector': 'th', 'props': [
            ('background-color', '#f6f6f6'),
            ('color', '#2e2a8c'),
            ('border','1px solid #000 !important'),
            ('padding','6px'),
            ('text-align','center')
        ]},
        {'selector': 'thead tr:first-child th:first-child', 'props': [
            ('background-color', '#f6f6f6'),
            ('color', 'black'),
            ('text-transform', 'none'),
            ('font-weight', 'bold')
        ]}
    ])
)

# %%
table4_b
# Out:
# <style type="text/css">
# #T_7d993 table {
#   border-collapse: collapse;
#   border: 2px solid #000;
# }
# #T_7d993 th {
#   border: 1px solid #000 !important;
#   padding: 6px;
#   text-align: center;
# }
# #T_7d993  td {
#   border: 1px solid #000 !important;
#   padding: 6px;
#   text-align: center;
# }
# #T_7d993 th {
#   background-color: #f6f6f6;
#   color: #2e2a8c;
#   border: 1px solid #000 !important;
#   padding: 6px;
#   text-align: center;
# }
# #T_7d993 thead tr:first-child th:first-child {
#   background-color: #f6f6f6;
#   color: black;
#   text-transform: none;
_col6, #T_7d993_row14_col7, #T_7d993_row14_col11, #T_7d993_row14_col14, #T_7d993_row14_col17, #T_7d993_row15_col4, #T_7d993_row15_col6, #T_7d993_row15_col8, #T_7d993_row15_col10, #T_7d993_row15_col13, #T_7d993_row15_col15, #T_7d993_row15_col18, #T_7d993_row16_col2, #T_7d993_row16_col11, #T_7d993_row16_col13, #T_7d993_row16_col15, #T_7d993_row16_col16, #T_7d993_row16_col18, #T_7d993_row16_col19, #T_7d993_row17_col15, #T_7d993_row18_col0, #T_7d993_row18_col1, #T_7d993_row18_col5, #T_7d993_row18_col8, #T_7d993_row18_col10, #T_7d993_row18_col13, #T_7d993_row18_col14, #T_7d993_row19_col1, #T_7d993_row19_col7, #T_7d993_row19_col9, #T_7d993_row19_col10, #T_7d993_row19_col12, #T_7d993_row19_col14 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_7d993_row0_col6, #T_7d993_row0_col7, #T_7d993_row1_col6, #T_7d993_row2_col11, #T_7d993_row3_col12, #T_7d993_row4_col2, #T_7d993_row4_col3, #T_7d993_row4_col4, #T_7d993_row4_col11, #T_7d993_row4_col17, #T_7d993_row4_col19, #T_7d993_row5_col2, #T_7d993_row5_col12, #T_7d993_row6_col2, #T_7d993_row6_col7, #T_7d993_row6_col8, #T_7d993_row6_col13, #T_7d993_row6_col17, #T_7d993_row7_col0, #T_7d993_row7_col3, #T_7d993_row7_col8, #T_7d993_row8_col19, #T_7d993_row9_col15, #T_7d993_row10_col10, #T_7d993_row10_col12, #T_7d993_row11_col16, #T_7d993_row13_col2, #T_7d993_row14_col0, #T_7d993_row14_col10, #T_7d993_row14_col19, #T_7d993_row15_col5, #T_7d993_row15_col12, #T_7d993_row15_col17, #T_7d993_row15_col19, #T_7d993_row16_col4, #T_7d993_row16_col5, #T_7d993_row16_col8, #T_7d993_row17_col3, #T_7d993_row18_col4, #T_7d993_row19_col2, #T_7d993_row19_col6 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_7d993_row0_col9, #T_7d993_row1_col10, #T_7d993_row1_col11, #T_7d993_row2_col4, #T_7d993_row2_col7, #T_7d993_row2_col10, #T_7d993_row2_col15, #T_7d993_row2_col17, #T_7d993_row2_col18, #T_7d993_row4_col6, #T_7d993_row4_col7, #T_7d993_row4_col9, #T_7d993_row4_col18, #T_7d993_row5_col0, #T_7d993_row5_col7, #T_7d993_row5_col9, #T_7d993_row5_col11, #T_7d993_row6_col0, #T_7d993_row7_col1, #T_7d993_row9_col1, #T_7d993_row9_col4, #T_7d993_row9_col13, #T_7d993_row11_col7, #T_7d993_row11_col11, #T_7d993_row11_col15, #T_7d993_row12_col1, #T_7d993_row12_col2, #T_7d993_row12_col6, #T_7d993_r

# %% [markdown]
# # Exercise 5

# %%
df5 = first_division[((first_division['home_team'] == 'Barcelona') & (df4['away_team'] == 'Real Madrid')) | ((first_division['home_team'] == 'Barcelona') & (first_division['away_team'] == 'Barcelona'))].copy()
# Barcelona and Real Madrid have never been in any other division (nor have Atletico de Madrid). We can work with the data from first_division without problems.

# %%
df5
# Out:
#           season  division  matchday      date     time  home_team  \
# 5      1928-1929         1         2   2/17/29     None  Barcelona
# 131    1929-1930         1         9   1/26/30     None  Barcelona
# 266    1930-1931         1        18    4/5/31     None  Barcelona
# 356    1931-1932         1        18    4/3/32     None  Barcelona
# 385    1932-1933         1         6    1/1/33     None  Barcelona
# ...          ...       ...       ...       ...      ...        ...
# 24049  2016-2017         1        14   12/3/16  4:15 PM  Barcelona
# 24656  2017-2018         1        36    5/6/18  8:45 PM  Barcelona
# 24775  2018-2019         1        10  10/28/18  4:15 PM  Barcelona
# 25157  2019-2020         1        10  12/18/19  8:00 PM  Barcelona
# 25499  2020-2021         1         7  10/24/20  4:00 PM  Barcelona
#
#          away_team score  home_goals  away_goals result  goal_difference
# 5      Real Madrid   1:2           1           2      2                1
# 131    Real Madrid   1:4           1           4      2                3
# 266    Real Madrid   3:1           3           1      1                2
# 356    Real Madrid   2:2           2           2      X                0
# 385    Real Madrid   1:1           1           1      X                0
# ...            ...   ...         ...         ...    ...              ...
# 24049  Real Madrid   1:1           1           1      X                0
# 24656  Real Madrid   2:2           2           2      X                0
# 24775  Real Madrid   5:1           5           1      1                4
# 25157  Real Madrid   0:0           0           0      X                0
# 25499  Real Madrid   1:3           1           3      2                2
#
# [91 rows x 12 columns]

# %%
def winner_from_row(row):
    if row['result'] == '1':
        return row['home_team']
    elif row['result'] == '2':
        return row['away_team']
    else:
        return 'Tie'

# %%
df5['who_won'] = df5.apply(winner_from_row, axis=1)

# %%
win_counts = df5['who_won'].value_counts().reindex(['Barcelona', 'Tie', 'Real Madrid']).fillna(0).astype(int)
win_counts
# Out:
# who_won
# Barcelona      50
# Tie            20
# Real Madrid    21
# Name: count, dtype: int64

# %%
goals_barca = (df5.loc[df5['home_team'] == 'Barcelona', 'home_goals'].sum() + df5.loc[df5['away_team'] == 'Barcelona', 'away_goals'].sum())
goals_barca
# Out:
# 179

# %%
goals_madrid = (df5.loc[df5['home_team'] == 'Real Madrid', 'home_goals'].sum() + df5.loc[df5['away_team'] == 'Real Madrid', 'away_goals'].sum())
goals_madrid
# Out:
# 108

# %%
goal_counts = [int(goals_barca), int(goals_madrid)]
goal_labels = ['Barcelona', 'Real Madrid']

# %%
fig, axes = plot.subplots(1, 2, sharey=True)

axes[0].pie(win_counts.values, labels=win_counts.index, autopct='%1.2f%%', startangle=90)
axes[0].set_title('Wins / Ties: Barça vs Madrid')

axes[1].pie(goal_counts, labels=goal_labels, autopct='%1.2f%%', startangle=90)
axes[1].set_title('Total Goals: Barça vs Madrid')

plot.show()

# %% [markdown]
# Now, let's creat a function that does all this.

# %%
def plot_direct_confrontations_stats(team1, team2, df, season=None):
    
    sub = df[((df['home_team'] == team1) & (df['away_team'] == team2)) | ((df['home_team'] == team2) & (df['away_team'] == team1))].copy()

    if season is not None:
        sub = sub[sub['season'] == season].copy()

    if sub.empty:
        print("No matches found between those teams with the current filters.")
        return None
        
    sub['who_won'] = np.where(sub['result'] == '1', sub['home_team'], np.where(sub['result'] == '2', sub['away_team'], 'Tie'))

    win_counts = sub['who_won'].value_counts().reindex([team1, 'Tie', team2]).fillna(0).astype(int)

    goals_team1 = (sub.loc[sub['home_team'] == team1, 'home_goals'].sum() + sub.loc[sub['away_team'] == team1, 'away_goals'].sum())
    
    goals_team2 = (sub.loc[sub['home_team'] == team2, 'home_goals'].sum() + sub.loc[sub['away_team'] == team2, 'away_goals'].sum())

    fig, axes = plot.subplots(1, 2, figsize=(10, 4))

    axes[0].pie(win_counts.values, labels=win_counts.index, autopct='%1.2f%%', startangle=90)
    axes[0].set_title(f'Wins / Ties: {team1} vs {team2}')

    axes[1].pie([int(goals_team1), int(goals_team2)], labels=[team1, team2], autopct='%1.2f%%', startangle=90)
    axes[1].set_title(f'Total Goals: {team1} vs {team2}')

    plot.tight_layout()
    plot.show()

# %%
plot_direct_confrontations_stats('Real Betis', 'Sevilla FC', valid_matches, None)

# %% [markdown]
# # Exercise 6

# %%
valid_matches['date_dt'] = pd.to_datetime(valid_matches['date'], errors='coerce')
mask = valid_matches['date_dt'].isna()
valid_matches.loc[mask, 'date_dt'] = pd.to_datetime(valid_matches.loc[mask, 'date'], dayfirst=True, errors='coerce')
# Out:
# /tmp/ipykernel_82954/303481903.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   valid_matches['date_dt'] = pd.to_datetime(valid_matches['date'], errors='coerce')

# %%
def team_matches(df, team):
    team_df = df[(df['home_team'] == team) | (df['away_team'] == team)].copy()
    team_df = team_df.sort_values('date_dt')
    
    def is_undefeated(row):
        if row['result'] == 'X':
            return True
        if row['result'] == '1' and row['home_team'] == team:
            return True
        if row['result'] == '2' and row['away_team'] == team:
            return True
        return False

    team_df['undefeated'] = team_df.apply(is_undefeated, axis=1)
    return team_df

# %%
def longest_streak(df, team):
    team_df = team_matches(df, team)
    team_df = team_df.sort_values('date_dt').reset_index(drop=True)

    longest = 0
    current = 0
    best_start = None
    best_end = None

    for i in range(len(team_df)):
        if team_df.loc[i, 'undefeated']:
            current += 1
            if current == 1:
                start = team_df.loc[i, 'date_dt']
            if current > longest:
                longest = current
                best_start = start
                best_end = team_df.loc[i, 'date_dt']
        else:
            current = 0

    if pd.notna(best_start):
        start_str = best_start.strftime('%d/%m/%Y')
    else:
        start_str = None

    if pd.notna(best_end):
        end_str = best_end.strftime('%d/%m/%Y')
    else:
        end_str = None
    
    return longest, start_str, end_str

# %%
longest_streak(valid_matches, 'Real Sociedad')
# Out:
# (38, '29/04/1979', '04/05/1980')

# %%
teams = sorted(set(valid_matches['home_team']).union(valid_matches['away_team']))

# %%
streaks_df = []
for t in teams:
    length, start, end = longest_streak(valid_matches, t)
    streaks_df.append({'team': t, 'streak': int(length), 'start': start, 'end': end})
streaks_df = pd.DataFrame(streaks_df)

# %%
top10 = streaks_df.sort_values('streak', ascending=False).head(10)

plot.figure(figsize=(8, 6))
plot.barh(top10['team'], top10['streak'])

plot.xlabel('Matches without losing')
plot.title('Longest undefeated streaks')

for i, row in enumerate(top10.itertuples()):
    plot.text(row.streak + 0.3, i, f"{row.start} - {row.end}", va='center', fontsize=8)

plot.show()

# %% [markdown]
# # Exercise 7

# %%
df7 = valid_matches.copy()

# %%
df7['result'] = df7['result'].astype(str)

# %%
home = df7[['season','division','home_team','home_goals','away_goals','result']].copy()

# %%
home = home.rename(columns={'home_team':'team', 'home_goals':'GF', 'away_goals':'GA'})
home['W'] = (home['result'] == '1').astype(int)
home['L'] = (home['result'] == '2').astype(int)
home['T'] = (home['result'] == 'X').astype(int)
home['Pts'] = home['W']*3 + home['T']*1

# %%
cols = ['season','division','team','GF','GA','W','L','T','Pts']
home = home[cols]

# %%
away = df7[['season','division','away_team','home_goals','away_goals','result']].copy()

# %%
away = away.rename(columns={'away_team':'team', 'away_goals':'GF', 'home_goals':'GA'})
away['W'] = (away['result'] == '2').astype(int)
away['L'] = (away['result'] == '1').astype(int)
away['T'] = (away['result'] == 'X').astype(int)
away['Pts'] = away['W']*3 + away['T']*1

# %%
away = away[cols]

# %%
long = pd.concat([home, away], ignore_index=True)
long
# Out:
#           season  division             team  GF  GA  W  L  T  Pts
# 0      1928-1929         1      Arenas Club   2   3  0  1  0    0
# 1      1928-1929         1         Espanyol   3   2  1  0  0    3
# 2      1928-1929         1      Real Madrid   5   0  1  0  0    3
# 3      1928-1929         1         Donostia   1   1  0  0  1    1
# 4      1928-1929         1           Racing   0   2  0  1  0    0
# ...          ...       ...              ...  ..  .. .. .. ..  ...
# 95995  2021-2022         2           Girona   1   2  0  1  0    0
# 95996  2021-2022         2       UD Almería   1   2  0  1  0    0
# 95997  2021-2022         2  Real Valladolid   2   0  1  0  0    3
# 95998  2021-2022         2   CF Fuenlabrada   0   0  0  0  1    1
# 95999  2021-2022         2         SD Eibar   1   0  1  0  0    3
#
# [96000 rows x 9 columns]

# %%
standings = (long.groupby(['season','division','team'], as_index=False).agg(GF=('GF','sum'), GA=('GA','sum'), W =('W','sum'), L =('L','sum'), T =('T','sum'), Pts=('Pts','sum')))

# %%
standings['GD'] = standings['GF'] - standings['GA']

# %%
num_cols = ['GF','GA','W','L','T','Pts','GD']
standings[num_cols] = standings[num_cols].astype(int)

# %%
standings = standings.sort_values(['season','division','Pts','GD','GF'], ascending=[False, True, False, False, False])

# %%
standings['rank'] = standings.groupby(['season','division'], sort=False).cumcount() + 1

# %%
standings
# Out:
#          season  division             team  GF  GA  W   L  T  Pts  GD  rank
# 2759  2021-2022         1      Real Madrid   8   4  2   0  1    7   4     1
# 2761  2021-2022         1       Sevilla FC   5   1  2   0  1    7   4     2
# 2762  2021-2022         1         Valencia   5   1  2   0  1    7   4     3
# 2747  2021-2022         1        Barcelona   7   4  2   0  1    7   3     4
# 2746  2021-2022         1  Atlético Madrid   5   3  2   0  1    7   2     5
# ...         ...       ...              ...  ..  .. ..  .. ..  ...  ..   ...
# 2     1928-1929         1  Athletic Madrid  43  41  8   8  2   26   2     6
# 6     1928-1929         1         Espanyol  32  38  7   7  4   25  -6     7
# 4     1928-1929         1        Catalunya  45  49  6   8  4   22  -4     8
# 9     1928-1929         1       Real Unión  40  42  5  11  2   17  -2     9
# 7     1928-1929         1           Racing  25  50  3  12  3   12 -25    10
#
# [2786 rows x 11 columns]

# %% [markdown]
# The only thing left is to expord it to .xlsx

# %%
dir = Path.cwd()
os.makedirs('reports', exist_ok=True)
out_path = os.path.join(dir, 'reports/SeasonStandings.xlsx')
standings.to_excel(out_path, index=False)
print("Saved:", out_path)
# Out:
# Saved: /home/noel/Documentos/R_and_I/quiniela/reports/SeasonStandings.xlsx
